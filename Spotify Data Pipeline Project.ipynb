# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="39048ecb8d744ed68dd50099355c5ba2", client_secret="3e1172bd30eb4724835567c1d28b1d65")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"

# %%
playlist_URI =playlist_link.split("/")[-1].split('?')[0]

# %%
data=sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]
# Out:
# {'added_at': '2024-11-15T15:43:48Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
# ...

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
# ...

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
# ...

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Die With A Smile'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-08-16'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'

# %%
album_list=[]
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'name': 'Die With A Smile',
#   'release_date': '2024-08-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  {'album_id': '2IYQwwgxgOIn7t3iF6ufFD',
#   'name': 'APT.',
#   'release_date': '2024-10-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2IYQwwgxgOIn7t3iF6ufFD'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'name': 'MUSE',
#   'release_date': '2024-07-19',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#  {'album_id': '0hBRqPYPXhr1RkTDG3n4Mk',
#   'name': 'The Secret of Us (Deluxe)',
#   'release_date': '2024-10-18',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/0hBRqPYPXhr1RkTDG3n4Mk'},
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2024-11-15T15:43:48Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
# ...

# %%
artist_list = []
seen_artists = set()  # To track already added artist IDs

for row in data['items']:
    if 'track' in row:  # Check if 'track' exists in the item
        for artist in row['track']['artists']:
            artist_id = artist['id']
            if artist_id not in seen_artists:  # Avoid duplicates
                artist_dict = {
                    'artist_id': artist_id,
                    'artist_name': artist['name'],
                    'external_url': artist['href']
                }
                artist_list.append(artist_dict)
                seen_artists.add(artist_id)

# %%
artist_list
# Out:
# [{'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '3eVa5w3URK5duf6eyVDbu9',
#   'artist_name': 'ROSÉ',
#   'external_url': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '1oSPZhvZMIrWW5I41kPkkY',
#   'artist_name': 'Jimin',
#   'external_url': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY'},
#  {'artist_id': '4tuJ0bMpJh08umKkEXKUI5',
#   'artist_name': 'Gracie Abrams',
#   'external_url': 'https://api.spotify.com/v1/artists/4tuJ0bMpJh08umKkEXKUI5'},
#  {'artist_id': '3l9G1G9MxH6DaRhwLklaf5',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '2plbrEY59IikOBgBGLjaoe',
#   'song_name': 'Die With A Smile',
#   'duration_ms': 251667,
#   'url': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe',
#   'popularity': 100,
#   'song_added': '2024-11-15T15:43:48Z',
#   'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms'},
#  {'song_id': '5vNRhkKd0yEAg8suGBpjeY',
#   'song_name': 'APT.',
#   'duration_ms': 169917,
#   'url': 'https://open.spotify.com/track/5vNRhkKd0yEAg8suGBpjeY',
#   'popularity': 98,
#   'song_added': '2024-11-15T15:43:48Z',
#   'album_id': '2IYQwwgxgOIn7t3iF6ufFD',
#   'artist_id': '3eVa5w3URK5duf6eyVDbu9'},
#  {'song_id': '6dOtVTDdiauQNBQEDOtlAB',
#   'song_name': 'BIRDS OF A FEATHER',
#   'duration_ms': 210373,
#   'url': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB',
#   'popularity': 97,
#   'song_added': '2024-11-15T15:43:48Z',
#   'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                       name release_date  \
# 0  10FLjwfpbxLmW8c25Xyc2N           Die With A Smile   2024-08-16
# 1  2IYQwwgxgOIn7t3iF6ufFD                       APT.   2024-10-18
# 2  7aJuG4TFXa2hmE4z1yxc3n       HIT ME HARD AND SOFT   2024-05-17
# 3  15XcLhiVMlSOipUddTNDnr                       MUSE   2024-07-19
# 4  0hBRqPYPXhr1RkTDG3n4Mk  The Secret of Us (Deluxe)   2024-10-18
#
#    total_tracks                                                url
# 0             1  https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 1             1  https://open.spotify.com/album/2IYQwwgxgOIn7t3...
# 2            10  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 3             7  https://open.spotify.com/album/15XcLhiVMlSOipU...
# 4            20  https://open.spotify.com/album/0hBRqPYPXhr1RkT...

# %%
song_df = pd.DataFrame.from_dict(song_list)
song_df.head()
# Out:
#                   song_id           song_name  duration_ms  \
# 0  2plbrEY59IikOBgBGLjaoe    Die With A Smile       251667
# 1  5vNRhkKd0yEAg8suGBpjeY                APT.       169917
# 2  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER       210373
# 3  7tI8dRuH2Yc6RuoTjxo4dU                 Who       170887
# 4  7ne4VBA60CxGM75vw0EYad      That’s So True       166300
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/2plbrEY59IikOBg...         100
# 1  https://open.spotify.com/track/5vNRhkKd0yEAg8s...          98
# 2  https://open.spotify.com/track/6dOtVTDdiauQNBQ...          97
# 3  https://open.spotify.com/track/7tI8dRuH2Yc6Ruo...          92
# 4  https://open.spotify.com/track/7ne4VBA60CxGM75...          93
#
#              song_added                album_id               artist_id
# 0  2024-11-15T15:43:48Z  10FLjwfpbxLmW8c25Xyc2N  1HY2Jd0NmPuamShAr6KMms
# 1  2024-11-15T15:43:48Z  2IYQwwgxgOIn7t3iF6ufFD  3eVa5w3URK5duf6eyVDbu9
# ...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  1HY2Jd0NmPuamShAr6KMms      Lady Gaga
# 1  0du5cEVh5yTK9QJze8zA0C     Bruno Mars
# 2  3eVa5w3URK5duf6eyVDbu9           ROSÉ
# 3  0du5cEVh5yTK9QJze8zA0C     Bruno Mars
# 4  6qqNVTkY8uBg9cP3Jd7DAH  Billie Eilish
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 1  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 2  https://api.spotify.com/v1/artists/3eVa5w3URK5...
# 3  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 4  https://api.spotify.com/v1/artists/6qqNVTkY8uB...

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     77 non-null     object
#  1   artist_name   77 non-null     object
#  2   external_url  77 non-null     object
# dtypes: object(3)
# memory usage: 1.9+ KB

# %%
data['items'][0]
# Out:
# {'added_at': '2024-11-15T15:43:48Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
# ...

# %%
artists
# Out:
# [{'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga'},
#  {'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars'}]
